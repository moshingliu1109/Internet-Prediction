# %% [markdown]
# ## Titanic Competition with TensorFlow Decision Forests
#
# This notebook shows some basic pre-processing, for example, the ticket names will be divided into sections and the passenger names will be tokenized. And also go through the steps to train a baseline Gradient boosted Trees (GBT) Model with default parameters using TensorFlow Decision Forests.
#
# ### Import dependencies

# %%
import numpy as np
import pandas as pd
import os

# !pip install tensorflow
# !pip install tensorflow_decision_forests

import tensorflow as tf
import tensorflow_decision_forests as tfdf

print(f"Found TF-DF {tfdf.__version__}")
# Out:
# Requirement already satisfied: tensorflow in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (2.14.0)
# Requirement already satisfied: tensorflow-macos==2.14.0 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (3.7.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (0.2.0)
# Requirement already satisfied: numpy>=1.23.5 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (23.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (4.24.4)
# Requirement already satisfied: setuptools in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (4.7.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (1.59.0)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow) (2.14.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.14.0->tensorflow) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (2.23.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow) (3.2.2)
# Requirement already satisfied: tensorflow_decision_forests in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (1.6.0)
# Requirement already satisfied: numpy in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow_decision_forests) (1.24.3)
# Requirement already satisfied: pandas in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow_decision_forests) (1.5.3)
# Requirement already satisfied: tensorflow~=2.14.0 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow_decision_forests) (2.14.0)
# Requirement already satisfied: six in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow_decision_forests) (1.16.0)
# Requirement already satisfied: absl-py in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow_decision_forests) (2.0.0)
# Requirement already satisfied: wheel in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow_decision_forests) (0.38.4)
# Requirement already satisfied: wurlitzer in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow_decision_forests) (3.0.2)
# Requirement already satisfied: tensorflow-macos==2.14.0 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow~=2.14.0->tensorflow_decision_forests) (2.14.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow~=2.14.0->tensorflow_decision_forests) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow~=2.14.0->tensorflow_decision_forests) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow~=2.14.0->tensorflow_decision_forests) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow~=2.14.0->tensorflow_decision_forests) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow~=2.14.0->tensorflow_decision_forests) (3.7.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow~=2.14.0->tensorflow_decision_forests) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow~=2.14.0->tensorflow_decision_forests) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow~=2.14.0->tensorflow_decision_forests) (3.3.0)
# Requirement already satisfied: packaging in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow~=2.14.0->tensorflow_decision_forests) (23.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow~=2.14.0->tensorflow_decision_forests) (4.24.4)
# Requirement already satisfied: setuptools in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow~=2.14.0->tensorflow_decision_forests) (68.0.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow~=2.14.0->tensorflow_decision_forests) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow~=2.14.0->tensorflow_decision_forests) (4.7.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow~=2.14.0->tensorflow_decision_forests) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow~=2.14.0->tensorflow_decision_forests) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow~=2.14.0->tensorflow_decision_forests) (1.59.0)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow~=2.14.0->tensorflow_decision_forests) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow~=2.14.0->tensorflow_decision_forests) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.14.0->tensorflow~=2.14.0->tensorflow_decision_forests) (2.14.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from pandas->tensorflow_decision_forests) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from pandas->tensorflow_decision_forests) (2022.7)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow~=2.14.0->tensorflow_decision_forests) (2.23.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow~=2.14.0->tensorflow_decision_forests) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow~=2.14.0->tensorflow_decision_forests) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow~=2.14.0->tensorflow_decision_forests) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow~=2.14.0->tensorflow_decision_forests) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow~=2.14.0->tensorflow_decision_forests) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow~=2.14.0->tensorflow_decision_forests) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow~=2.14.0->tensorflow_decision_forests) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow~=2.14.0->tensorflow_decision_forests) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow~=2.14.0->tensorflow_decision_forests) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow~=2.14.0->tensorflow_decision_forests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow~=2.14.0->tensorflow_decision_forests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow~=2.14.0->tensorflow_decision_forests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow~=2.14.0->tensorflow_decision_forests) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow~=2.14.0->tensorflow_decision_forests) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow~=2.14.0->tensorflow_decision_forests) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/moshingliu/anaconda3/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-macos==2.14.0->tensorflow~=2.14.0->tensorflow_decision_forests) (3.2.2)
# Found TF-DF 1.6.0

# %% [markdown]
# ### Load datasets

# %%
train_df = pd.read_csv("/Users/moshingliu/Desktop/项目实习XDF/互联网项目/train.csv")
test_df = pd.read_csv("/Users/moshingliu/Desktop/项目实习XDF/互联网项目/test.csv")

train_df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %% [markdown]
# ### Prepare dataset
#
# We will apply transformations on the dataset.

# %%
def preprocess(df):
    df = df.copy()
    
    def normalize_name(x):
        return " ".join([v.strip(",()[].\"'") for v in x.split(" ")])
    
    def ticket_number(x):
        return x.split(" ")[-1]
        
    def ticket_item(x):
        items = x.split(" ")
        if len(items) == 1:
            return "NONE"
        return "_".join(items[0:-1])
    
    df["Name"] = df["Name"].apply(normalize_name)
    df["Ticket_number"] = df["Ticket"].apply(ticket_number)
    df["Ticket_item"] = df["Ticket"].apply(ticket_item)                     
    return df
    
preprocessed_train_df = preprocess(train_df)
preprocessed_test_df = preprocess(test_df)

preprocessed_train_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                               Name     Sex   Age  SibSp  \
# 0                            Braund Mr Owen Harris    male  22.0      1
# 1  Cumings Mrs John Bradley Florence Briggs Thayer  female  38.0      1
# 2                             Heikkinen Miss Laina  female  26.0      0
# 3         Futrelle Mrs Jacques Heath Lily May Peel  female  35.0      1
# 4                           Allen Mr William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Ticket_number Ticket_item
# 0      0         A/5 21171   7.2500   NaN        S         21171         A/5
# 1      0          PC 17599  71.2833   C85        C         17599          PC
# 2      0  STON/O2. 3101282   7.9250   NaN        S       3101282    STON/O2.
# 3      0            113803  53.1000  C123        S        113803        NONE
# 4      0            373450   8.0500   NaN        S        373450        NONE

# %%
input_features = list(preprocessed_train_df.columns)
input_features.remove("Ticket")
input_features.remove("PassengerId")
input_features.remove("Survived")
#input_features.remove("Ticket_number")

print(f"Input features: {input_features}")
# Out:
# Input features: ['Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Cabin', 'Embarked', 'Ticket_number', 'Ticket_item']

# %% [markdown]
# ### Convert Pandas dataset to TensorFlow Dataset

# %%
def tokenize_names(features, labels=None):
    """Divite the names into tokens. TF-DF can consume text tokens natively."""
    features["Name"] =  tf.strings.split(features["Name"])
    return features, labels

train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(preprocessed_train_df,label="Survived").map(tokenize_names)
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(preprocessed_test_df).map(tokenize_names)

# %% [markdown]
# ### Train model with default parameters
#
# #### Train model
# First, we are training a Gradient Boosted Trees Model with the default parameters.

# %%
model = tfdf.keras.GradientBoostedTreesModel(
    verbose=0,
    features=[tfdf.keras.FeatureUsage(name=n) for n in input_features],
    exclude_non_specified_features=True,
    random_seed=1234,
)
model.fit(train_ds)

self_evaluation = model.make_inspector().evaluation()
print(f"Accuracy: {self_evaluation.accuracy} Loss:{self_evaluation.loss}")
# Out:
# [WARNING 23-10-19 23:01:35.2129 EDT gradient_boosted_trees.cc:1830] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 23-10-19 23:01:35.2130 EDT gradient_boosted_trees.cc:1841] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 23-10-19 23:01:35.2130 EDT gradient_boosted_trees.cc:1855] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Accuracy: 0.804347813129425 Loss:0.8922085165977478
# [INFO 23-10-19 23:01:35.4418 EDT kernel.cc:1233] Loading model from path /var/folders/09/74dcx6ys20v6brjfqswsm1gm0000gn/T/tmpkmyrb2bd/model/ with prefix 0a13d9a3f2314d69
# [INFO 23-10-19 23:01:35.4435 EDT abstract_model.cc:1344] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO 23-10-19 23:01:35.4436 EDT kernel.cc:1061] Use fast generic engine

# %% [markdown]
# ### Train model with improved default parameters
#
# Then we will use some specific parameters when creating the GBT model.

# %%
model = tfdf.keras.GradientBoostedTreesModel(
    verbose=0,
    features=[tfdf.keras.FeatureUsage(name=n) for n in input_features],
    exclude_non_specified_features=True,
    min_examples=1,
    categorical_algorithm="RANDOM",
    shrinkage=0.05,
    split_axis="SPARSE_OBLIQUE",
    sparse_oblique_normalization="MIN_MAX",
    sparse_oblique_num_projections_exponent=2.0,
    num_trees=2000,
    random_seed=1234,
    
)
model.fit(train_ds)

self_evaluation = model.make_inspector().evaluation()
print(f"Accuracy: {self_evaluation.accuracy} Loss:{self_evaluation.loss}")
# Out:
# [WARNING 23-10-19 23:12:06.6285 EDT gradient_boosted_trees.cc:1830] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# [WARNING 23-10-19 23:12:06.6287 EDT gradient_boosted_trees.cc:1841] "goss_beta" set but "sampling_method" not equal to "GOSS".
# [WARNING 23-10-19 23:12:06.6287 EDT gradient_boosted_trees.cc:1855] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# Accuracy: 0.77173912525177 Loss:1.0119096040725708
# [INFO 23-10-19 23:12:06.9968 EDT kernel.cc:1233] Loading model from path /var/folders/09/74dcx6ys20v6brjfqswsm1gm0000gn/T/tmphm_zbb82/model/ with prefix dfa88ff065b44edb
# [INFO 23-10-19 23:12:07.0019 EDT decision_forest.cc:660] Model loaded with 54 root(s), 2824 node(s), and 10 input feature(s).
# [INFO 23-10-19 23:12:07.0019 EDT abstract_model.cc:1344] Engine "GradientBoostedTreesGeneric" built
# [INFO 23-10-19 23:12:07.0019 EDT kernel.cc:1061] Use fast generic engine

# %% [markdown]
# Then, summarized the model and noticed the information about variable importance that the model figured out.

# %%
model.summary()
# Out:
# Model: "gradient_boosted_trees_model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (11):
# 	Age
# 	Cabin
# 	Embarked
# 	Fare
# 	Name
# 	Parch
# 	Pclass
# 	Sex
# 	SibSp
# 	Ticket_item
# 	Ticket_number
#
# No weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.           "Sex"  0.431313 ################
#     2.           "Age"  0.373986 ############
#     3.          "Fare"  0.250863 ####
#     4.          "Name"  0.225272 ###
#     5.   "Ticket_item"  0.182111
#     6.      "Embarked"  0.181387
#     7. "Ticket_number"  0.180897
#     8.        "Pclass"  0.178279
#     9.         "Parch"  0.175249
#    10.         "SibSp"  0.172167
#
# Variable Importance: NUM_AS_ROOT:
#     1.  "Sex" 39.000000 ################
#     2. "Name" 12.000000 ####
#     3.  "Age"  3.000000
#
# Variable Importance: NUM_NODES:
#     1.           "Age" 677.000000 ################
#     2.          "Fare" 388.000000 #########
#     3.          "Name" 97.000000 ##
#     4.   "Ticket_item" 66.000000 #
#     5.           "Sex" 51.000000 #
#     6.         "Parch" 31.000000
#     7. "Ticket_number" 27.000000
#     8.      "Embarked" 26.000000
#     9.        "Pclass" 14.000000
#    10.         "SibSp"  8.000000
#
# Variable Importance: SUM_SCORE:
#     1.           "Age" 438.353539 ################
#     2.           "Sex" 437.300923 ###############
#     3.          "Fare" 310.070332 ###########
#     4.          "Name" 172.193127 ######
#     5.        "Pclass" 46.099034 #
#     6.   "Ticket_item" 32.422949 #
#     7. "Ticket_number" 24.092083
#     8.      "Embarked" 10.681472
#     9.         "Parch"  8.623476
#    10.         "SibSp"  2.142252
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 1.01191
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 54
# Total number of nodes: 2824
#
# Number of nodes by tree:
# Count: 54 Average: 52.2963 StdDev: 5.8393
# Min: 37 Max: 61 Ignored: 0
# ----------------------------------------------
# [ 37, 38)  1   1.85%   1.85% #
# [ 38, 39)  0   0.00%   1.85%
# [ 39, 40)  1   1.85%   3.70% #
# [ 40, 42)  2   3.70%   7.41% ##
# [ 42, 43)  0   0.00%   7.41%
# [ 43, 44)  2   3.70%  11.11% ##
# [ 44, 45)  0   0.00%  11.11%
# [ 45, 47)  3   5.56%  16.67% ###
# [ 47, 48)  1   1.85%  18.52% #
# [ 48, 49)  0   0.00%  18.52%
# [ 49, 50)  6  11.11%  29.63% ######
# [ 50, 52)  6  11.11%  40.74% ######
# [ 52, 53)  0   0.00%  40.74%
# [ 53, 54) 10  18.52%  59.26% ##########
# [ 54, 55)  0   0.00%  59.26%
# [ 55, 57)  7  12.96%  72.22% #######
# [ 57, 58)  5   9.26%  81.48% #####
# [ 58, 59)  0   0.00%  81.48%
# [ 59, 60)  6  11.11%  92.59% ######
# [ 60, 61]  4   7.41% 100.00% ####
#
# Depth by leafs:
# Count: 1439 Average: 4.84434 StdDev: 0.463491
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)    5   0.35%   0.35%
# [ 3, 4)   45   3.13%   3.47%
# [ 4, 5)  119   8.27%  11.74% #
# [ 5, 5] 1270  88.26% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 1439 Average: 29.9833 StdDev: 74.0766
# Min: 1 Max: 474 Ignored: 0
# ----------------------------------------------
# [   1,  24) 1144  79.50%  79.50% ##########
# [  24,  48)   92   6.39%  85.89% #
# [  48,  72)   59   4.10%  89.99% #
# [  72,  95)   16   1.11%  91.10%
# [  95, 119)   20   1.39%  92.49%
# [ 119, 143)   12   0.83%  93.33%
# [ 143, 166)   29   2.02%  95.34%
# [ 166, 190)   11   0.76%  96.11%
# [ 190, 214)    4   0.28%  96.39%
# [ 214, 238)    2   0.14%  96.53%
# [ 238, 261)    4   0.28%  96.80%
# [ 261, 285)    3   0.21%  97.01%
# [ 285, 309)    3   0.21%  97.22%
# [ 309, 332)    1   0.07%  97.29%
# [ 332, 356)    4   0.28%  97.57%
# [ 356, 380)   10   0.69%  98.26%
# [ 380, 403)    7   0.49%  98.75%
# [ 403, 427)   13   0.90%  99.65%
# [ 427, 451)    1   0.07%  99.72%
# [ 451, 474]    4   0.28% 100.00%
#
# Attribute in nodes:
# 	677 : Age [NUMERICAL]
# 	388 : Fare [NUMERICAL]
# 	97 : Name [CATEGORICAL_SET]
# 	66 : Ticket_item [CATEGORICAL]
# 	51 : Sex [CATEGORICAL]
# 	31 : Parch [NUMERICAL]
# 	27 : Ticket_number [CATEGORICAL]
# 	26 : Embarked [CATEGORICAL]
# 	14 : Pclass [NUMERICAL]
# 	8 : SibSp [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	39 : Sex [CATEGORICAL]
# 	12 : Name [CATEGORICAL_SET]
# 	3 : Age [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	65 : Age [NUMERICAL]
# 	39 : Sex [CATEGORICAL]
# 	26 : Fare [NUMERICAL]
# 	17 : Name [CATEGORICAL_SET]
# 	6 : Pclass [NUMERICAL]
# 	4 : Ticket_number [CATEGORICAL]
# 	3 : Embarked [CATEGORICAL]
# 	1 : Ticket_item [CATEGORICAL]
# 	1 : Parch [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	171 : Age [NUMERICAL]
# 	81 : Fare [NUMERICAL]
# 	40 : Sex [CATEGORICAL]
# 	34 : Name [CATEGORICAL_SET]
# 	13 : Embarked [CATEGORICAL]
# 	12 : Ticket_item [CATEGORICAL]
# 	11 : Ticket_number [CATEGORICAL]
# 	7 : Pclass [NUMERICAL]
# 	3 : Parch [NUMERICAL]
# 	1 : SibSp [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	349 : Age [NUMERICAL]
# 	199 : Fare [NUMERICAL]
# 	58 : Name [CATEGORICAL_SET]
# 	41 : Sex [CATEGORICAL]
# 	37 : Ticket_item [CATEGORICAL]
# 	24 : Ticket_number [CATEGORICAL]
# 	19 : Embarked [CATEGORICAL]
# 	13 : Parch [NUMERICAL]
# 	7 : Pclass [NUMERICAL]
# 	3 : SibSp [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	677 : Age [NUMERICAL]
# 	388 : Fare [NUMERICAL]
# 	97 : Name [CATEGORICAL_SET]
# 	66 : Ticket_item [CATEGORICAL]
# 	51 : Sex [CATEGORICAL]
# 	31 : Parch [NUMERICAL]
# 	27 : Ticket_number [CATEGORICAL]
# 	26 : Embarked [CATEGORICAL]
# 	14 : Pclass [NUMERICAL]
# 	8 : SibSp [NUMERICAL]
#
# Condition type in nodes:
# 	1118 : ObliqueCondition
# 	199 : ContainsBitmapCondition
# 	68 : ContainsCondition
# Condition type in nodes with depth <= 0:
# 	51 : ContainsBitmapCondition
# 	3 : ObliqueCondition
# Condition type in nodes with depth <= 1:
# 	98 : ObliqueCondition
# 	61 : ContainsBitmapCondition
# 	3 : ContainsCondition
# Condition type in nodes with depth <= 2:
# 	263 : ObliqueCondition
# 	94 : ContainsBitmapCondition
# 	16 : ContainsCondition
# Condition type in nodes with depth <= 3:
# 	571 : ObliqueCondition
# 	145 : ContainsBitmapCondition
# 	34 : ContainsCondition
# Condition type in nodes with depth <= 5:
# 	1118 : ObliqueCondition
# 	199 : ContainsBitmapCondition
# 	68 : ContainsCondition
#
# Training logs:
# Number of iteration to final model: 54
# 	Iter:1 train-loss:1.267642 valid-loss:1.363407  train-accuracy:0.624531 valid-accuracy:0.543478
# 	Iter:2 train-loss:1.216613 valid-loss:1.329323  train-accuracy:0.624531 valid-accuracy:0.543478
# 	Iter:3 train-loss:1.169435 valid-loss:1.301666  train-accuracy:0.624531 valid-accuracy:0.543478
# 	Iter:4 train-loss:1.121583 valid-loss:1.264140  train-accuracy:0.624531 valid-accuracy:0.543478
# 	Iter:5 train-loss:1.079456 valid-loss:1.237068  train-accuracy:0.794743 valid-accuracy:0.717391
# 	Iter:6 train-loss:1.043708 valid-loss:1.215828  train-accuracy:0.824781 valid-accuracy:0.717391
# 	Iter:16 train-loss:0.791781 valid-loss:1.102193  train-accuracy:0.902378 valid-accuracy:0.739130
# 	Iter:26 train-loss:0.651576 valid-loss:1.061744  train-accuracy:0.921151 valid-accuracy:0.771739
# 	Iter:36 train-loss:0.564274 valid-loss:1.043167  train-accuracy:0.924906 valid-accuracy:0.760870
# 	Iter:46 train-loss:0.494652 valid-loss:1.021948  train-accuracy:0.936170 valid-accuracy:0.760870
# 	Iter:56 train-loss:0.442437 valid-loss:1.015255  train-accuracy:0.943680 valid-accuracy:0.771739
# 	Iter:66 train-loss:0.405156 valid-loss:1.020953  train-accuracy:0.949937 valid-accuracy:0.782609
# 	Iter:76 train-loss:0.374286 valid-loss:1.032522  train-accuracy:0.952441 valid-accuracy:0.771739
